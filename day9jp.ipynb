# %%
import cv2
import skimage
import matplotlib.pyplot as plt

# %% [markdown]
# Image type conversion
# > color image to grayscale
#
# >to binary
#
# geometric transformation
# >cropping
#
# >scaling
#
# >rotation
#
# image arthmetic /brightness, contrast adjustment
# >addition
#
# >subtraction
#
# >multiplication
#
# >division
#
# >brightness and contrast adjustment
#
# morpholory
# >structuring element
# >
# >
# >
#
# fearture detection
# >

# %%
img1= plt.imread("pic2.jpg")
plt.imshow(img1[:,:,::-1])

# %%
img_gray=cv2.cvtColor(img1,cv2.COLOR_BGR2GRAY)
img_gray.shape
# Out:
# (873, 1280)

# %%
plt.imshow(img_gray,cmap='gray')

# %%
th ,img_bin=cv2.threshold(img_gray,100,255,cv2.THRESH_BINARY)
img_bin.shape
# Out:
# (873, 1280)

# %%
plt.imshow(img_bin,cmap='gray')

# %%
#image cropping
plt.imshow(img1[300:700,400:800,::-1])

# %%
x,y,w,h=(50,150,100,140)
plt.imshow(img1[y:y+h,x:x+w,::-1])
plt.show()
x1,y1,x2,y2=(50,150,270,230)
plt.imshow(img1[y1:y2,x1:x2,::-1])
plt.show()

# %%
# image scaling 
img_large=cv2.resize(img1,(1500,1500),interpolation=cv2.INTER_CUBIC)
plt.imshow(img_large[:,:,::-1])
img_large.shape
# Out:
# (1500, 1500, 3)

# %%
img_small=cv2.resize(img1,(150,150),interpolation=cv2.INTER_CUBIC)
plt.imshow(img_small[:,:,::-1])
img_small.shape
# Out:
# (150, 150, 3)

# %%
img_small=cv2.resize(img1,(0,0), fx=0.25,fy=0.25,interpolation=cv2.INTER_CUBIC)
plt.imshow(img_small[:,:,::-1])
img_small.shape
# Out:
# (218, 320, 3)

# %%
# image rotate 
img_90=cv2.rotate(img1,cv2.ROTATE_90_CLOCKWISE)
plt.imshow(img_90[:,:,::-1])

# %%
img_x=ski.tranform.rotate(img1,-30)
plt.imshow(img_x[:,:,::-1])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\prata\Desktop\AIDL\day9jp.ipynb Cell 14 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/prata/Desktop/AIDL/day9jp.ipynb#X22sZmlsZQ%3D%3D?line=0'>1</a> img_x=ski.tranform.rotate(img1,-30)
#       <a href='vscode-notebook-cell:/c%3A/Users/prata/Desktop/AIDL/day9jp.ipynb#X22sZmlsZQ%3D%3D?line=1'>2</a> plt.imshow(img_x[:,:,::-1])
#
# NameError: name 'ski' is not defined
