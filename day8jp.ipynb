# %%
import cv2
import skimage
import matplotlib.pyplot as plt

# %%
cv2.__version__
# Out:
# '4.8.0'

# %%
skimage.__version__
# Out:
# '0.19.2'

# %% [markdown]
# open/show/save an image

# %%
img1= plt.imread("pic1.jpg")
plt.imshow(img1)
plt.axis("off")
plt.show()
img1.shape
# Out:
# (1500, 2000, 3)

# %%
img2=cv2.imread("pic2.jpg")
cv2.imshow("Image",img2)
cv2.waitKey(0)
# Out:
# 13

# %%
img2.shape
# Out:
# (873, 1280, 3)

# %%
img3=skimage.io.imread("pic3.jpg")
skimage.io.imshow(img3)
img3.shape
# Out:
# (459, 612, 3)

# %%
type(img1), type(img2), type(img3)
# Out:
# (numpy.ndarray, numpy.ndarray, numpy.ndarray)

# %%
import numpy as np
r1=np.random.randint(0,255,(459, 612, 3))
plt.imshow(r1)

# %%
r2=np.random.randint(0,255,(459, 612))
plt.imshow(r2,cmap='gray')

# %%
r2=np.random.randint(0,255,(45, 61))
plt.imshow(r2,cmap='gray')
#skimage.io.imshow(r2,cmap='gray')

# %%
img=np.ones([50,50,3],dtype='uint8')*255
img[:25,:25,1:]=0       #img[:25,:25,1:]*0
img[:25,25:,::2]=0      #img[:25,25:,::2]*0
img[25:,:25,:2]=0       #img[25:,:25,:2]*0
img[25:,25:,2:]=0       #img[25:,25:,2:]*0
plt.imshow(img)

# %%
plt.imsave('squarebox.png',img)

# %%
skimage.io.imsave('squarebox2.png',img)
# Out:
# Lossy conversion from float64 to uint8. Range [0.0, 255.0]. Convert image to uint8 prior to saving to suppress this warning.

# %%
cv2.imwrite('squarebox3.png',img)
# Out:
# True

# %%
skimage.io.imsave('squarebox4.png',img)
